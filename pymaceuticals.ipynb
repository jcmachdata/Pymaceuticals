# %% [markdown]
# ## Analysis
#
# * For the purposes of this study, three drugs (Capomulin, Infubinol, Ketapril) and a placebo were evaluated for their effectiveness at reducing tumor size in mice. With regards to tumor size, Capomulin was the only drug that showed efficacy. Mice treated with Capomulin showed a 19.5% reduction in tumor size after 45 days.
# * Both Capomulin and Infubinol were effective and decreasing the rate of metastic spread. The sites averaged 1.48 and 2.11, respectively, while mice that were given placebo averaged 3.27.
# * Capomulin was the only drug effective at increasing the survival rate of the mice. Mice that were given placebo had a survival rate of 44%, while mice who were given Capomulin had a survival rate of 84%.
# * Although the "Tumor Response to Treatment" graph appears to show that Ketapril may actually increase tumor size, a t-test reveals a p-value of 0.83 indicating no significant difference from placebo.

# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# Files to Load
mouse_drug_data_to_load = "data/mouse_drug_data.csv"
clinical_trial_data_to_load = "data/clinicaltrial_data.csv"

# %%
# Read the Mouse and Drug Data and the Clinical Trial Data
mouse_df = pd.read_csv(mouse_drug_data_to_load)
clinical_df = pd.read_csv(clinical_trial_data_to_load)

# %%
mouse_df.head()
# Out:
#   Mouse ID      Drug
# 0     f234  Stelasyn
# 1     x402  Stelasyn
# 2     a492  Stelasyn
# 3     w540  Stelasyn
# 4     v764  Stelasyn

# %%
clinical_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
# Combine the data into a single dataset
df_c = pd.merge(mouse_df, clinical_df, how="outer", on="Mouse ID")

# %%
# Display the data table for preview
df_c.head()
# Out:
#   Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     f234  Stelasyn          0           45.000000                 0
# 1     f234  Stelasyn          5           47.313491                 0
# 2     f234  Stelasyn         10           47.904324                 0
# 3     f234  Stelasyn         15           48.735197                 1
# 4     f234  Stelasyn         20           51.112713                 2

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
df_group = df_c.groupby(['Drug', 'Timepoint'])
df_group = df_group['Tumor Volume (mm3)'].mean()
df_group = pd.DataFrame(df_group)

# %%
df_group.head()
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                   45.000000
#           5                   44.266086
#           10                  43.084291
#           15                  42.064317
#           20                  40.716325

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
stored_sems = df_c.groupby(['Drug', 'Timepoint']).sem()['Tumor Volume (mm3)']

# Convert to DataFrame
stored_sems_df = pd.DataFrame(stored_sems)

# Preview DataFrame
stored_sems_df.head()
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                    0.000000
#           5                    0.448593
#           10                   0.702684
#           15                   0.838617
#           20                   0.909731

# %%
# Minor Data Munging to Re-Format the Data Frames
df_group_rf = df_group.pivot_table('Tumor Volume (mm3)',['Timepoint'],('Drug'))
# Preview that Reformatting worked
df_group_rf
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# ...

# %%
# Generate the Plot (with Error Bars)
formats = [('Capomulin','o','red'), ('Infubinol','^','blue'), ('Ketapril','s','green'), ('Placebo','d','black')]

for drug, marker, color in formats:
    sems_tumor = stored_sems[drug]
    plot_treat = plt.errorbar(df_group_rf.index, df_group_rf[drug], sems_tumor, fmt=marker, ls='--', color=color, linewidth=0.5)

plt.title('Tumor Response to Treatment')
plt.xlabel('Time (Days)')
plt.ylabel('Tumor Volume (mm3)')
plt.legend(loc='best')
plt.grid()

# Save the Figure
plt.savefig("Tumor_Response.jpg")

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
df_group_met = df_c.groupby(['Drug', 'Timepoint'])
df_group_met = df_group_met['Metastatic Sites'].mean()

# Convert to DataFrame
df_group_met = pd.DataFrame(df_group_met)

# Preview DataFrame
df_group_met.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
stored_sems_met = df_c.groupby(['Drug', 'Timepoint']).sem()['Metastatic Sites']

# Convert to DataFrame
stored_sems_met_df = pd.DataFrame(stored_sems_met)

# Preview DataFrame
stored_sems_met_df.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621

# %%
# Minor Data Munging to Re-Format the Data Frames
df_group_met_rf = df_group_met.pivot_table('Metastatic Sites',['Timepoint'],('Drug'))

# Preview that Reformatting worked
df_group_met_rf
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
# 25          0.818182  1.500000   1.277778  1.631579  1.500000  1.941176
# 30          1.090909  1.937500   1.588235  2.055556  2.066667  2.266667
# 35          1.181818  2.071429   1.666667  2.294118  2.266667  2.642857
# 40          1.380952  2.357143   2.100000  2.733333  2.466667  3.166667
# 45          1.476190  2.692308   2.111111  3.363636  2.538462  3.272727
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# Generate the Plot (with Error Bars)
formats = [('Capomulin','o','red'), ('Infubinol','^','blue'), ('Ketapril','s','green'), ('Placebo','d','black')]

for drug, marker, color in formats:
    sems_tumor_met = stored_sems_met[drug]
    plot_treat = plt.errorbar(df_group_met_rf.index, df_group_met_rf[drug], sems_tumor_met, fmt=marker, ls='--', color=color, linewidth=0.5)

plt.title('Metastatic Spread During Treatment')
plt.xlabel('Time (Days)')
plt.ylabel('Metastatic Sites')
plt.legend(loc='best')
plt.grid()

# Save the Figure
plt.savefig("Metastatic_Spread.jpg")

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)
df_group_mice = df_c.groupby(['Drug','Timepoint'])
df_group_mice = df_group_mice['Mouse ID'].count()

# Convert to DataFrame
df_group_mice = pd.DataFrame(df_group_mice)
df_group_mice = df_group_mice.rename(columns={'Mouse ID': 'Mouse Count'})

# Preview DataFrame
df_group_mice.head()
# Out:
#                      Mouse Count
# Drug      Timepoint
# Capomulin 0                   25
#           5                   25
#           10                  25
#           15                  24
#           20                  23

# %%
# Minor Data Munging to Re-Format the Data Frames
df_group_mice_rf = df_group_mice.pivot_table('Mouse Count',['Timepoint'],('Drug'))

# Preview the Data Frame
df_group_mice_rf.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# 10               23        24        23         22
# 15               17        24        23         21
# 20               17        23        21         17

# %%
# Generate the Plot (Accounting for percentages)
formats = [('Capomulin','o','red'), ('Infubinol','^','blue'), ('Ketapril','s','green'), ('Placebo','d','black')]

for drug, marker, color in formats:
     plot_survival = plt.plot(df_group_mice_rf.index, 100*df_group_mice_rf[drug]/25, marker=marker, ls='--', color=color, linewidth=0.5)

plt.title('Survival During Treatment')
plt.xlabel('Time (Days)')
plt.ylabel('Survival Rate (%)')
plt.legend(loc='best')
plt.grid()
        
# Save the Figure
plt.savefig("Survival.jpg")

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug
percent_change = 100*(df_group_rf.loc[45] - df_group_rf.loc[0])/df_group_rf.loc[0]

# Display the data to confirm
percent_change
# Out:
# Drug
# Capomulin   -19.475303
# Ceftamin     42.516492
# Infubinol    46.123472
# Ketapril     57.028795
# Naftisol     53.923347
# Placebo      51.297960
# Propriva     47.241175
# Ramicane    -22.320900
# Stelasyn     52.085134
# Zoniferol    46.579751
# dtype: float64

# %%
# Drop all unwanted drugs
percent_change = percent_change.drop(index=["Ceftamin","Naftisol","Propriva","Ramicane","Stelasyn","Zoniferol"])

# Splice the data between passing and failing drugs
positive = []
positive_x = []
negative = []
negative_x = []

for x in range(0,4):
    if percent_change[x] > 0:
        positive.append(percent_change[x])
        positive_x.append(percent_change.index[x])
    else:
        negative.append(percent_change[x])
        negative_x.append(percent_change.index[x])

# %%
# Orient widths. Add labels, tick marks, etc. 
plt.bar(negative_x, negative, width=1, color='g', alpha=1, align="edge")
plt.bar(positive_x, positive, width=1, color='r', alpha=1, align="edge")

plt.yticks(np.arange(-20, 70, step=20))
plt.grid()
plt.title('Tumor Change Over 45 Day Treatment')
plt.ylabel('Tumor Volume Change (%)')

# Label the percentages of changes
count = 0.5
for x in percent_change:
    if x < 0:
        y_coor = -4.5
    else:
        y_coor = 2
    plt.text(count, y_coor, str(round(x, 1))+'%', ha='center', color='white')
    count += 1

# Save the Figure
plt.savefig("Tumor_Change.jpg")

# %%
#calculate p value for Ketapril versus Placebo in tumor reduction
(t_stat, p) = ttest_ind(df_group_rf['Ketapril'], df_group_rf['Placebo'], equal_var=False)

# %%
p
# Out:
# 0.8298632170774808
